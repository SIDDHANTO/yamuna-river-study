# %%
# !python -m pip install -U scikit-learn scipy matplotlib
# Out:
# Requirement already up-to-date: scikit-learn in c:\python\lib\site-packages (0.22.2.post1)
# Requirement already up-to-date: scipy in c:\python\lib\site-packages (1.4.1)
# Requirement already up-to-date: matplotlib in c:\python\lib\site-packages (3.2.1)
# ...
# WARNING: You are using pip version 20.0.2; however, version 20.1 is available.
# You should consider upgrading via the 'C:\python\python.exe -m pip install --upgrade pip' command.

# %%
import random # library for random number generation
import numpy as np # library for vectorized computation
import pandas as pd # library to process data as dataframes
# http://localhost:8888/notebooks/yamuna_analysis.ipynb#
import matplotlib.pyplot as plt # plotting library
# backend for rendering plots within the browser
# %matplotlib inline 

from sklearn.cluster import KMeans 
from sklearn.datasets.samples_generator import make_blobs

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize                       
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'AFASFBLYAKDCQM4LCK3FQQEW2AUBYCZ030QUDDO3PHHDKVPY' # your Foursquare ID
CLIENT_SECRET = 'TVRJWDL2BTM4FDLVM1EIU2FIBGQPKV3FEZF3RC0KE4TOWS2B' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: AFASFBLYAKDCQM4LCK3FQQEW2AUBYCZ030QUDDO3PHHDKVPY
# CLIENT_SECRET:TVRJWDL2BTM4FDLVM1EIU2FIBGQPKV3FEZF3RC0KE4TOWS2B

# %%
x=pd.read_csv('water_quality_of_river_yamuna-2014.csv',encoding= 'LATIN1')

# %%
x
# Out:
#     STATION CODE                                          LOCATIONS  \
# 0           1494                  YAMUNA AT U/S OF LAKHWAR DAM, U.P
# 1           1490           YAMUNA AT U/S DAK PATTHAR, UTTAR PARDESH
# 2           1553                     YAMUNA , U/S PAONTA SAHIB, H.P
# 3           1554                     YAMUNA , D/S PAONTA SAHIB, H.P
# 4           1120                   YAMUNA AT WAZIRABAD, DELHI, CPCB
# 5           1121                        YAMUNA AT NIZAMUDDIN, DELHI
# 6           1375  YAMUNA AT OKHLA BRIDGE (INLET OF AGRA CANAL), ...
# 7           2495                      YAMUNA AT KESIGHAT, VRINDAVAN
# 8           1123                       YAMUNA AT MATHURA U/S , U.P.
# 9           2494                     YAMUNA AT VISHRAMGHAT, MATHURA
# 10          1124                       YAMUNA AT MATHURA D/S , U.P.
# 11          1125                           YAMUNA AT AGRA U/S, U.P.
# 12          1126                        YAMUNA AT D/S OF AGRA, U.P.
# ...

# %%
y=pd.read_csv('RS_Session_248_AS_79.1.csv',encoding= 'unicode_escape')

# %%
y
# Out:
#         Sl. No.          Category  \
# 0             1             Delhi
# 1             2             Delhi
# 2             3             Delhi
# 3             4             Delhi
# 4             5             Delhi
# 5             6             Delhi
# 6             7             Delhi
# 7             8             Delhi
# 8     Sub Total             Delhi
# 9             9             Delhi
# 10           10             Delhi
# 11           11             Delhi
# 12     SubTotal             Delhi
# 13        Total             Delhi
# 14            1  Himachal Pradesh
# 15            1           Haryana
# 16            2           Haryana
# 17            1     Uttar Pradesh
# 18            2     Uttar Pradesh
# 19            3     Uttar Pradesh
# 20        Total     Uttar Pradesh
# 21  Grand Total       Grand Total
#
#                             Name of Project Component  \
# 0   "Rehabilitation of Trunk Sewer No. 4, (K1)" in...
# ...

# %%
delhi=y[0:14]

# %%
delhi
# Out:
#       Sl. No. Category                          Name of Project Component  \
# 0           1    Delhi  "Rehabilitation of Trunk Sewer No. 4, (K1)" in...
# 1           2    Delhi  "Rehabilitation of Trunk Sewer No.5 (K2)" in K...
# 2           3    Delhi  "Providing and Laying Pressure Mains of 700-90...
# 3           4    Delhi  "Rehabilitation of Sewers of sizes varying fro...
# 4           5    Delhi  "Providing and Laying 1200 mm dia. DI Rising M...
# 5           6    Delhi  "Rehabilitation & Up-gradation of existing 182...
# 6           7    Delhi  "Rehabilitation and Up-gradation of Kondli Pha...
# 7           8    Delhi  "Construction of 564 MLD (124 MGD) WWTP at Okh...
# 8   Sub Total    Delhi                                          Sub Total
# 9           9    Delhi  Construction of 318 MLD (70 MGD) WWTP with 10 ...
# 10         10    Delhi  Construction of SPSs and 9 nos of Decentralize...
# 11         11    Delhi   Extension and Redevelopment work for Chhath Ghat
# ...

# %%
delhi['Name of Project Component']
# Out:
# 0     "Rehabilitation of Trunk Sewer No. 4, (K1)" in...
# 1     "Rehabilitation of Trunk Sewer No.5 (K2)" in K...
# 2     "Providing and Laying Pressure Mains of 700-90...
# 3     "Rehabilitation of Sewers of sizes varying fro...
# 4     "Providing and Laying 1200 mm dia. DI Rising M...
# 5     "Rehabilitation & Up-gradation of existing 182...
# 6     "Rehabilitation and Up-gradation of Kondli Pha...
# 7     "Construction of 564 MLD (124 MGD) WWTP at Okh...
# 8                                             Sub Total
# 9     Construction of 318 MLD (70 MGD) WWTP with 10 ...
# 10    Construction of SPSs and 9 nos of Decentralize...
# 11     Extension and Redevelopment work for Chhath Ghat
# 12                                             SubTotal
# 13                                                Total
# Name: Name of Project Component, dtype: object

# %%
x=delhi['Completion Year']
y=delhi['AA&ES Cost (Rs. In crore)']
plt.scatter( x,y)
plt.title('Budget and year relation')
plt.ylabel('COST')
plt.xlabel('year')
plt.show()

# %%
address1 = 'Shastri Park Metro Station New Delhi'

geolocator = Nominatim(user_agent="foursquare_agent")
location3 = geolocator.geocode(address1)
latitude3 = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Shastri Park Metro Station New DelhI
# Out:
# 28.63092935 77.25634998299665

# %%
 address2 = 'YAMUNA BANK '

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address2)
latitude1 = location.latitude
longitude1 = location.longitude
print(latitude, longitude)
# YAMUNA BANK
# Out:
# 28.63092935 77.25634998299665

# %%
address3 = 'Yamuna River,EAST DELHI '

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address3)
latitude2 = location.latitude
longitude2 = location.longitude
print(latitude, longitude)
# YAMUNA BANK
#Yamuna River
# Out:
# 28.63092935 77.25634998299665

# %%
address4 = 'Yamuna Bank '

# geolocator = Nominatim(user_agent="foursquare_agent")
# location = geolocator.geocode(address4)
# latitude = location.latitude
# longitude = location.longitude
# print(latitude, longitude)
# # YAMUNA BANK
# #Yamuna River
# Out:
# 27.1242347 78.3695769

# %%
search_query = 'YAMUNA'
radius = 500
print(search_query + ' .... OK!')
# Out:
# YAMUNA .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=AFASFBLYAKDCQM4LCK3FQQEW2AUBYCZ030QUDDO3PHHDKVPY&client_secret=TVRJWDL2BTM4FDLVM1EIU2FIBGQPKV3FEZF3RC0KE4TOWS2B&ll=27.1242347,78.3695769&v=20180604&query=YAMUNA&radius=500&limit=30'

# %%
import folium
m = folium.Map(location=[latitude, longitude])

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(
    location=[latitude1, latitude1],
    zoom_start=12,
    tiles='Stamen Terrain'
)

folium.Marker(
    location=[latitude1, latitude1],
    popup='1',
    icon=folium.Icon(icon='cloud')
).add_to(m)

folium.Marker(
    location=[latitude2, latitude2],
    popup='2',
    icon=folium.Icon(color='green')
).add_to(m)

folium.Marker(
    location=[latitude3, latitude2],
    popup='3',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(
    location=[28.7041, 77.1025],
    zoom_start=12,
    tiles='Stamen Terrain'
)

folium.Marker(
    location=[45.3288, -121.6625],
    popup='Mt. Hood Meadows',
    icon=folium.Icon(icon='cloud')
).add_to(m)

folium.Marker(
    location=[45.3311, -121.7113],
    popup='Timberline Lodge',
    icon=folium.Icon(color='green')
).add_to(m)

folium.Marker(
    location=[45.3300, -121.6823],
    popup='Some Other Location',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
y=pd.read_csv('water_quality_2012_river_yamuna.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-130-9c8eb36035ef> in <module>
# ----> 1 y=pd.read_csv('water_quality_2012_river_yamuna.csv')
#
# c:\python\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
y=pd.read_csv('rs_session_239_AS159_1.2.csv',encoding = 'unicode_escape')

# %%
y
# Out:
#                              DRAINS FALLING IN YAMUNA  \
# 0                             NAJAFGARH DRAIN (DELHI)
# 1                         MAGZINE ROAD DRAIN ( DELHI)
# 2                        SWEEPER COLONY DRAIN (DELHI)
# 3                           KHYBER PASS DRAIN (DELHI)
# 4                         METCALF HOUSE DRAIN (DELHI)
# 5                      ISBT + MORI GATE DRAIN (DELHI)
# 6                           TONGA STAND DRAIN (DELHI)
# 7                         KAILASH NAGAR DRAIN (DELHI)
# 8                            CIVIL MILL DRAIN (DELHI)
# 9                           POWER HOUSE DRAIN (DELHI)
# 10                     SEN NURSING HOME DRAIN (DELHI)
# 11                                DRAIN NO.14 (DELHI)
# 12                            BARAPULLA DRAIN (DELHI)
# 13                        MAHARANI BAGH DRAIN (DELHI)
# 14                           TUGLAKABAD DRAIN (DELHI)
# 15                            ABU FAZAL DRAIN (DELHI)
# ...

# %%
y=pd.read_csv('water_quality_of_river_yamuna-2014.csv',encoding = 'unicode_escape')

# %%
y
# Out:
#     STATION CODE                                          LOCATIONS  \
# 0           1494                  YAMUNA AT U/S OF LAKHWAR DAM, U.P
# 1           1490           YAMUNA AT U/S DAK PATTHAR, UTTAR PARDESH
# 2           1553                     YAMUNA , U/S PAONTA SAHIB, H.P
# 3           1554                     YAMUNA , D/S PAONTA SAHIB, H.P
# 4           1120                   YAMUNA AT WAZIRABAD, DELHI, CPCB
# 5           1121                        YAMUNA AT NIZAMUDDIN, DELHI
# 6           1375  YAMUNA AT OKHLA BRIDGE (INLET OF AGRA CANAL), ...
# 7           2495                      YAMUNA AT KESIGHAT, VRINDAVAN
# 8           1123                       YAMUNA AT MATHURA U/S , U.P.
# 9           2494                     YAMUNA AT VISHRAMGHAT, MATHURA
# 10          1124                       YAMUNA AT MATHURA D/S , U.P.
# 11          1125                           YAMUNA AT AGRA U/S, U.P.
# 12          1126                        YAMUNA AT D/S OF AGRA, U.P.
# ...
